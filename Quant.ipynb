# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_as_array = mpimg.imread('palm_trees.jpg')
image_as_array
# Out:
# array([[[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 23,  63,  98],
#         [ 51,  91, 127],
#         [ 50,  90, 126]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 31,  71, 106],
#         [ 48,  88, 124],
#         [ 47,  90, 125]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 39,  79, 114],
#         [ 42,  85, 120],
#         [ 44,  88, 123]],
#
#        ...,
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [  9,   9,  11],
#         [  9,   9,  11]],
#
#        [[  3,   3,   5],
#         [  3,   3,   5],
#         [  3,   3,   5],
#         ...,
#         [  8,   8,  10],
#         [  8,   8,  10],
#         [  8,   8,  10]],
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [ 10,  10,  12],
#         [ 10,  10,  12]]], shape=(1401, 934, 3), dtype=uint8)

# %%
plt.figure(figsize = (6,6),dpi=200)
plt.imshow(image_as_array)

# %%
image_as_array.shape
# Out:
# (1401, 934, 3)

# %%
(h,w,c)=image_as_array.shape
image_as_array2d=image_as_array.reshape(h*w,c)

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=6)
model
# Out:
# KMeans(n_clusters=6)

# %%
labels=model.fit_predict(image_as_array2d)
labels
# Out:
# array([3, 3, 3, ..., 0, 0, 0], shape=(1308534,), dtype=int32)

# %%
model.cluster_centers_
# Out:
# array([[  2.77058309,   2.57124563,   3.68132513],
#        [191.31149013, 154.49773586, 109.7555489 ],
#        [218.9928282 , 135.65641108,  47.38332267],
#        [ 71.33451588, 109.28411433, 137.56015178],
#        [ 67.35721379,  61.68101759,  61.9510675 ],
#        [136.82331401, 143.76282594, 143.89456654]])

# %%
rgb_codes=model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[  3,   3,   4],
#        [191, 154, 110],
#        [219, 136,  47],
#        [ 71, 109, 138],
#        [ 67,  62,  62],
#        [137, 144, 144]])

# %%
quat_image=np.reshape(rgb_codes[labels],(h,w,c))
quat_image
# Out:
# array([[[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 67,  62,  62],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        [[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 67,  62,  62],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        [[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        ...,
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]]], shape=(1401, 934, 3))

# %%
plt.figure(figsize = (6,6),dpi=200)
plt.imshow(quat_image)
